# %%
import pandas as pd
import h2o
h2o.init()

train = pd.read_csv("../../datasets/classification/train.csv")
test = pd.read_csv("../../datasets/classification/test.csv")
# Out:
# Checking whether there is an H2O instance running at http://localhost:54321 ..... not found.
# Attempting to start a local H2O server...
# ---------------------------------------------------------------------------
# H2OConnectionError                        Traceback (most recent call last)
# File c:\Users\micmi\miniconda3\lib\site-packages\h2o\h2o.py:270, in init(url, ip, port, name, https, cacert, insecure, username, password, cookies, proxy, start_h2o, nthreads, ice_root, log_dir, log_level, max_log_file_size, enable_assertions, max_mem_size, min_mem_size, strict_version_check, ignore_config, extra_classpath, jvm_custom_args, bind_to_localhost, **kwargs)
#     269 try:
# --> 270     h2oconn = H2OConnection.open(url=url, ip=ip, port=port, name=name, https=https,
#     271                                  verify_ssl_certificates=verify_ssl_certificates, cacert=cacert,
#     272                                  auth=auth, proxy=proxy, cookies=cookies, verbose=True,
#     273                                  msgs=("Checking whether there is an H2O instance running at {url} ",
#     274                                        "connected.", "not found."),
#     275                                  strict_version_check=svc)
#     276 except H2OConnectionError:
#     277     # Backward compatibility: in init() port parameter really meant "baseport" when starting a local server...
#
# File c:\Users\micmi\miniconda3\lib\site-packages\h2o\backend\connection.py:386, in H2OConnection.open(server, url, ip, port, name, https, auth, verify_ssl_certificates, cacert, proxy, cookies, verbose, msgs, strict_version_check)
#     385 conn._timeout = 3.0
# --> 386 conn._cluster = conn._test_connection(retries, messages=msgs)
#     387 # If a server is unable to respond within 1s, it should be considered a bug. However we disable this
#     388 # setting for now, for no good reason other than to ignore all those bugs :(
#
# File c:\Users\micmi\miniconda3\lib\site-packages\h2o\backend\connection.py:690, in H2OConnection._test_connection(self, max_retries, messages)
#     689 else:
# --> 690     raise H2OConnectionError("Could not establish link to the H2O cloud %s after %d retries\n%s"
#     691                              % (self._base_url, max_retries, "\n".join(errors)))
#
# H2OConnectionError: Could not establish link to the H2O cloud http://localhost:54321 after 5 retries
# [51:30.01] H2OConnectionError: Unexpected HTTP error: HTTPConnectionPool(host='localhost', port=54321): Max retries exceeded with url: /3/Metadata/schemas/CloudV3 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x0000019FE257F850>: Failed to establish a new connection: [WinError 10061] Impossibile stabilire la connessione. Rifiuto persistente del computer di destinazione'))
# [51:34.30] H2OConnectionError: Unexpected HTTP error: HTTPConnectionPool(host='localhost', port=54321): Max retries exceeded with url: /3/Metadata/schemas/CloudV3 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x0000019FE258C550>: Failed to establish a new connection: [WinError 10061] Impossibile stabilire la connessione. Rifiuto persistente del computer di destinazione'))
# [51:38.62] H2OConnectionError: Unexpected HTTP error: HTTPConnectionPool(host='localhost', port=54321): Max retries exceeded with url: /3/Metadata/schemas/CloudV3 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x0000019FDD1969A0>: Failed to establish a new connection: [WinError 10061] Impossibile stabilire la connessione. Rifiuto persistente del computer di destinazione'))
# [51:42.91] H2OConnectionError: Unexpected HTTP error: HTTPConnectionPool(host='localhost', port=54321): Max retries exceeded with url: /3/Metadata/schemas/CloudV3 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x0000019FE25BA490>: Failed to establish a new connection: [WinError 10061] Impossibile stabilire la connessione. Rifiuto persistente del computer di destinazione'))
# [51:47.22] H2OConnectionError: Unexpected HTTP error: HTTPConnectionPool(host='localhost', port=54321): Max retries exceeded with url: /3/Metadata/schemas/CloudV3 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x0000019FE25BAEB0>: Failed to establish a new connection: [WinError 10061] Impossibile stabilire la connessione. Rifiuto persistente del computer di destinazione'))
#
# During handling of the above exception, another exception occurred:
#
# H2OStartupError                           Traceback (most recent call last)
# c:\Users\micmi\Documents\Università\UniBo\ml-project-work\h20\classification\main.ipynb Cella 1 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/Users/micmi/Documents/Universit%C3%A0/UniBo/ml-project-work/h20/classification/main.ipynb#ch0000000?line=0'>1</a> import pandas as pd
#       <a href='vscode-notebook-cell:/c%3A/Users/micmi/Documents/Universit%C3%A0/UniBo/ml-project-work/h20/classification/main.ipynb#ch0000000?line=1'>2</a> import h2o
# ----> <a href='vscode-notebook-cell:/c%3A/Users/micmi/Documents/Universit%C3%A0/UniBo/ml-project-work/h20/classification/main.ipynb#ch0000000?line=2'>3</a> h2o.init()
#       <a href='vscode-notebook-cell:/c%3A/Users/micmi/Documents/Universit%C3%A0/UniBo/ml-project-work/h20/classification/main.ipynb#ch0000000?line=4'>5</a> train = pd.read_csv("../../datasets/classification/train.csv")
#       <a href='vscode-notebook-cell:/c%3A/Users/micmi/Documents/Universit%C3%A0/UniBo/ml-project-work/h20/classification/main.ipynb#ch0000000?line=5'>6</a> test = pd.read_csv("../../datasets/classification/test.csv")
#
# File c:\Users\micmi\miniconda3\lib\site-packages\h2o\h2o.py:287, in init(url, ip, port, name, https, cacert, insecure, username, password, cookies, proxy, start_h2o, nthreads, ice_root, log_dir, log_level, max_log_file_size, enable_assertions, max_mem_size, min_mem_size, strict_version_check, ignore_config, extra_classpath, jvm_custom_args, bind_to_localhost, **kwargs)
#     283     if https:
#     284         raise H2OConnectionError('Starting local server is not available with https enabled. You may start local'
#     285                                  ' instance of H2O with https manually '
#     286                                  '(https://docs.h2o.ai/h2o/latest-stable/h2o-docs/welcome.html#new-user-quick-start).')
# --> 287     hs = H2OLocalServer.start(nthreads=nthreads, enable_assertions=enable_assertions, max_mem_size=mmax,
#     288                               min_mem_size=mmin, ice_root=ice_root, log_dir=log_dir, log_level=log_level,
#     289                               max_log_file_size=max_log_file_size, port=port, name=name,
#     290                               extra_classpath=extra_classpath, jvm_custom_args=jvm_custom_args,
#     291                               bind_to_localhost=bind_to_localhost)
#     292     h2oconn = H2OConnection.open(server=hs, https=https, verify_ssl_certificates=verify_ssl_certificates,
#     293                                  cacert=cacert, auth=auth, proxy=proxy, cookies=cookies, verbose=True,
#     294                                  strict_version_check=svc)
#     295 h2oconn.cluster.timezone = "UTC"
#
# File c:\Users\micmi\miniconda3\lib\site-packages\h2o\backend\server.py:140, in H2OLocalServer.start(jar_path, nthreads, enable_assertions, max_mem_size, min_mem_size, ice_root, log_dir, log_level, max_log_file_size, port, name, extra_classpath, verbose, jvm_custom_args, bind_to_localhost)
#     137     hs._tempdir = hs._ice_root
#     139 if verbose: print("Attempting to start a local H2O server...")
# --> 140 hs._launch_server(port=port, baseport=baseport, nthreads=int(nthreads), ea=enable_assertions,
#     141                   mmax=max_mem_size, mmin=min_mem_size, jvm_custom_args=jvm_custom_args,
#     142                   bind_to_localhost=bind_to_localhost, log_dir=log_dir, log_level=log_level, max_log_file_size=max_log_file_size)
#     143 if verbose: print("  Server is running at %s://%s:%d" % (hs.scheme, hs.ip, hs.port))
#     144 atexit.register(lambda: hs.shutdown())
#
# File c:\Users\micmi\miniconda3\lib\site-packages\h2o\backend\server.py:272, in H2OLocalServer._launch_server(self, port, baseport, mmax, mmin, ea, nthreads, jvm_custom_args, bind_to_localhost, log_dir, log_level, max_log_file_size)
#     269 self._ip = "127.0.0.1"
#     271 # Find Java and check version. (Note that subprocess.check_output returns the output as a bytes object)
# --> 272 java = self._find_java()
#     273 self._check_java(java, self._verbose)
#     275 if self._verbose:
#
# File c:\Users\micmi\miniconda3\lib\site-packages\h2o\backend\server.py:444, in H2OLocalServer._find_java()
#     441                 return os.path.join(dirpath, java)
#     443 # not found...
# --> 444 raise H2OStartupError("Cannot find Java. Please install the latest JRE from\n"
#     445                       "http://docs.h2o.ai/h2o/latest-stable/h2o-docs/welcome.html#java-requirements")
#
# H2OStartupError: Cannot find Java. Please install the latest JRE from
# http://docs.h2o.ai/h2o/latest-stable/h2o-docs/welcome.html#java-requirements
